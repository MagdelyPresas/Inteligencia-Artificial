# %% [markdown]
# <a href="https://colab.research.google.com/github/MagdelyPresas/Inteligencia-Artificial/blob/main/IA_Ejercicio1_MagdelyPresas_1921175.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Actividad 2.- Ejercicios en Python
#María Magdely Presas Huerta    Matrícula:1921175     Hora: N4

# %%
#Ejercicio 1
nom=input("Ingresa tu nombre: ") #Se utiliza la función input 
a="Ana"
b="Pedro"
c="Juan"
if nom==a or nom==b or nom==c:
  print("No se permite este nombre")
else: 
  print("Hola",nom)
# Out:
# Ingresa tu nombre: Ana
# No se permite este nombre

# %%
#Ejercicio 2
lista=[1,2,3,4,5,6,7]
print(lista)
print(lista[-1]) #El índice -1 se refiere al último elemento de la lista
lista.reverse() #Indica que se revierta el orden de la lista 
print(lista)
# Out:
# [1, 2, 3, 4, 5, 6, 7]
# 7
# [7, 6, 5, 4, 3, 2, 1]

# %%
#Ejercicio 3 
lista=["Hola", "a","*todos","esto","es","un","marco"]
print("************")
for tXt in lista: 
  print("*"+ tXt.ljust(10," ") + "*")
print("************")
# Out:
# ************
# *Hola      *
# *a         *
# **todos    *
# *esto      *
# *es        *
# *un        *
# *marco     *
# ************
